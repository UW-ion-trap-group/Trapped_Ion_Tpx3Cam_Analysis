# %%
import numpy as np
import scipy
import scipy.signal
import scipy.optimize
from scipy.optimize import curve_fit
from scipy import stats
import scipy.stats
import statistics as st
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d
import glob
import time
import pandas as pd
import math
import importlib

#import File_functions
plt.rcParams["figure.figsize"] = (3,3)


### Call the modules that have both the File information and the functions to perform the analysis ###
import Ion_functions
from Ion_functions import Ion
import choose_file 
importlib.reload(choose_file)
importlib.reload(Ion_functions)

print (time.ctime())
# Out:
# Sat Aug  7 00:02:09 2021

# %%
#modified threshold; threshold= 0.03/N where N is the min# photons per integration time 

choose_file.Trans_4ions_370V_1() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4



Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = False
single_photon = False
kind="auto"
threshold=0.004285714
ion_1.setup(threshold,kind,sigma,uncertainty, single_photon)
threshold=0.003333333
ion_2.setup(threshold,kind,sigma,uncertainty, single_photon)
threshold=0.003333333
ion_3.setup(threshold,kind,sigma,uncertainty, single_photon)
threshold=0.003750000
ion_4.setup(threshold,kind,sigma,uncertainty, single_photon)


xs_4_370V_1 = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
ys_4_370V_1 = [ion_1.y, ion_2.y, ion_3.y, ion_4.y]

rate_4_370V_1= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, 
              len(ion_4.transpts)/time]

# %%
#threshold=0.0043 for all ions 
plt.scatter(xs_4_370V_1,rate_4_370V_1)

# %%
# %store rate_4_370V_1b
# Out:
# Stored 'rate_4_370V_1b' (list)

# %%
#every ion has a different threshold based on the 0.03/N calculation 
plt.scatter(xs_4_370V_1,rate_4_370V_1)

# %%
import importlib
importlib.reload(Ion_functions)
import Ion_functions as func
from Ion_functions import Ion

# %%
# original,statistical method using 2 sigma 

choose_file.Trans_4ions_370V_1() #file selection, plots ROI's to verify number and location of Ions. 
ion_1 = choose_file.ion_1
ion_2 = choose_file.ion_2
ion_3 = choose_file.ion_3
ion_4 = choose_file.ion_4



Ion_1 = choose_file.Ion_1
Ion_2 = choose_file.Ion_2
Ion_3 = choose_file.Ion_3
Ion_4 = choose_file.Ion_4


filename = choose_file.filename
old_data_table = choose_file.old_data_table
data_table = choose_file.data_table
time = data_table['time'].max() - data_table['time'].min()


sigma = 2
uncertainty = False
single_photon = False
kind="auto"
threshold=0.004285714
ion_1.setup(threshold,kind,sigma,uncertainty, single_photon)
threshold=0.003333333
ion_2.setup(threshold,kind,sigma,uncertainty, single_photon)
threshold=0.003333333
ion_3.setup(threshold,kind,sigma,uncertainty, single_photon)
threshold=0.003750000
ion_4.setup(threshold,kind,sigma,uncertainty, single_photon)


rate_4_370V_1b= [len(ion_1.transpts)/time, len(ion_2.transpts)/time, len(ion_3.transpts)/time, 
              len(ion_4.transpts)/time]
# Out:
# 0.005293766367181553
# 0.00514033769822826
# 0.004825200952779455
# 0.005063995396705766

# %%
xs_4_370V_1 = [ion_1.x, ion_2.x, ion_3.x, ion_4.x]
plt.scatter(xs_4_370V_1,rate_4_370V_1b)

# %%
plt.scatter(xs_4_370V_1,rate_4_370V_1b,color="b",label="statistical")
plt.scatter(xs_4_370V_1,rate_4_370V_1,color="r",label="new method")
plt.xlabel("Ion Position")
plt.ylabel("transition rate")
plt.legend(bbox_to_anchor=(2,0))

# %%
#new method 
ion_1.visRange(100,8)
