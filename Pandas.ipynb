# %%
import re
import os 
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
import pandas as pd
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())
# Out:
# Tue Nov 30 23:11:45 2021

# %% [markdown]
# Beam Location <br>
# <b> z= 500; y= 149; x= 289.5 </b>

# %%
filename = '180V/8ions_600sec'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#      y   x    time  center flux  cluster size
# 0  223  89       0         1825             7
# 1   95  44  388352         1775             7

# %%
fig,ax=plt.subplots(figsize=(5, 5))

n=8 #number of ions 

h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,30,36,41,46,52.5,59,67,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              # upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values within bounds
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]

print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
ax0.set_title(filename)
# Out:
#  24.0 93.0
#  32.0 93.0
#  38.0 93.0
#  44.0 91.0
#  49.0 92.0
#  55.0 93.0
#  61.0 93.0
#  68.0 93.0
# Text(0.5, 1.0, '180V/8ions_600sec')

# %%
filename = '180V/8ions_1200sec'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#      y   x     time  center flux  cluster size
# 0   47   6        0         1725             8
# 1  147  35  3921920         2575             7

# %%
fig,ax=plt.subplots(figsize=(5, 5))

n=8 #number of ions 

h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,29,35,41,46,52,58,66,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
ax0.set_title(filename)
# Out:
#  23.0 92.0
#  30.0 92.0
#  37.0 92.0
#  42.0 91.0
#  48.0 91.0
#  53.0 92.0
#  60.0 92.0
#  67.0 92.0
# Text(0.5, 1.0, '180V/8ions_1200sec')

# %%
filename = '180V/8ions_1200sec_2'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)

# %%
fig,ax=plt.subplots(figsize=(5, 5))

n=8 #number of ions 

h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,29,35,41,46,52,58,66,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
print (filename)
# Out:
#  23.0 92.0
#  30.0 92.0
#  37.0 92.0
#  42.0 91.0
#  48.0 91.0
#  53.0 92.0
#  60.0 92.0
#  67.0 92.0
# 180V/8ions_1200sec

# %% [markdown]
# None of the files has any breaks. Cleared to join.

# %% [markdown]
# #### Merging 180V

# %%
filename = '180V/8ions_600sec'
it = pd.read_csv(filename)
print (len(it))

filename = '180V/8ions_1200sec'
it_1 = pd.read_csv(filename)
print (len(it_1))

filename = '180V/8ions_1200sec_2'
it_2 = pd.read_csv(filename)
print (len(it_2))
# Out:
# 10925716
# 20906504
# 19621484

# %%
it_1["time"]+=max(it["time"])
print ((len(it_1)))
# Out:
# 20906504

# %%
it_2["time"]+=max(it_1["time"])

# %%
meta=pd.concat([it,it_1,it_2])
meta.drop("Unnamed: 0",axis=1,inplace=True)
meta.head(2)
# Out:
#      y   x    time  center flux  cluster size
# 0  223  89       0         1825             7
# 1   95  44  388352         1775             7

# %%
fig,ax=plt.subplots(figsize=(5, 5))
n=8 #number of ions 

it=meta 
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,29,35,41,46,52,58,66,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
#  23.0 93.0
#  31.0 93.0
#  37.0 92.0
#  43.0 91.0
#  48.0 91.0
#  54.0 92.0
#  60.0 92.0
#  67.0 92.0
# (0, 3038306957807.8125)

# %%
meta.to_csv("8ions_180V_meta")

# %% [markdown]
# ### 130 V
#
# x_389.5_y_149

# %%
filename = '130V/8ions_1200sec'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#      y   x     time  center flux  cluster size
# 0   92  61        0          325             1
# 1  103  50  7976192         1375             4

# %%
fig,ax=plt.subplots(figsize=(5, 5))

n=8 #number of ions 

h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,24,30,39,46,52.5,59,67,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
ax0.set_title(filename)
# Out:
#  20.0 93.0
#  28.0 92.0
#  35.0 93.0
#  42.0 93.0
#  49.0 93.0
#  56.0 93.0
#  63.0 93.0
#  71.0 92.0
# Text(0.5, 1.0, '130V/8ions_1200sec')

# %%
filename = '130V/8ions_1200sec_2'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#     y   x     time  center flux  cluster size
# 0  89  55        0         1200             6
# 1  91  56  2906368         1925             7

# %%
fig,ax=plt.subplots(figsize=(5, 5))

n=8 #number of ions 

h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,24,30,39,46,52.5,59,67,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
ax0.set_title(filename)
# Out:
#  20.0 93.0
#  28.0 92.0
#  35.0 92.0
#  42.0 92.0
#  49.0 93.0
#  55.0 92.0
#  63.0 93.0
#  71.0 92.0
# Text(0.5, 1.0, '130V/8ions_1200sec_2')

# %%
filename = '130V/8ions_1200sec_3'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#      y    x     time  center flux  cluster size
# 0   33  139        0         2075            12
# 1  112   14  7604480         2875            12

# %%
fig,ax=plt.subplots(figsize=(5, 5))

n=8 #number of ions 

h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,24,30,39,46,52.5,59,67,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)

#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
ax0.set_title(filename)
# Out:
#  20.0 92.0
#  28.0 92.0
#  35.0 92.0
#  42.0 92.0
#  49.0 92.0
#  56.0 92.0
#  63.0 92.0
#  71.0 92.0
# Text(0.5, 1.0, '130V/8ions_1200sec_3')

# %% [markdown]
# No breaks; Cleared to merge.
#
# #### Merging 130V

# %%
filename = '130V/8ions_1200sec'
it = pd.read_csv(filename)
print (len(it))

filename = '130V/8ions_1200sec_2'
it_1 = pd.read_csv(filename)
print (len(it_1))

filename = '130V/8ions_1200sec_3'
it_2 = pd.read_csv(filename)
print (len(it_2))
# Out:
# 22226069
# 20506299
# 18705360

# %%
it_1["time"]+=max(it["time"])
print ((len(it_1)))
# Out:
# 20506299

# %%
it_2["time"]+=max(it_1["time"])

# %%
meta=pd.concat([it,it_1,it_2])
meta.drop("Unnamed: 0",axis=1,inplace=True)
len(meta)-(22226069+20506299+18705360)
# Out:
# 0

# %%
fig,ax=plt.subplots(figsize=(5, 5))
n=8 #number of ions 

it=meta 
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
x_left,x_right,y_bottom,y_top=15,75,75,110 #estimated after visualizing h2d above
ax.set_xlim(x_left,x_right)    #left and right limits on plot
ax.set_ylim(y_bottom,y_top)    #top and bottom limits

grid_x=[15,24,30,39,46,52.5,59,67,75] #sub-section boundaries (1 more than ions)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))                                           # empty  n by 2 matrix 
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]   # sub-dataframe for x values between 
                                                              #upper and lower bounds of box
    

    temp_2=temp.groupby(["x",'y']).size().idxmax()          #most frequently occuring x and y values
                                                             #in given "grid box"
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]                #append values to our array


x1=a[0][0]; y1=a[0][1]; x2=a[1][0]; y2=a[1][1]; x3=a[2][0]; y3=a[2][1]; x4=a[3][0]; y4=a[3][1]; 
x5=a[4][0]; y5=a[4][1]; x6=a[5][0]; y6=a[5][1]; x7=a[6][0]; y7=a[6][1]; x8=a[7][0]; y8=a[7][1]
print ("\n",x1,y1,"\n",x2,y2,"\n",x3,y3,"\n",x4,y4,"\n",x5,y5,"\n",x6,y6,"\n",x7,y7,"\n",x8,y8)


fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
t=(it["time"]*25/(4096))                                   # in ns
h = ax0.hist2d(it['x'], t, bins = [256, 400])

ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')
ax0.set_title(filename)


#it['time'].max()
start = 0; end = t.max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
#  20.0 93.0
#  28.0 92.0
#  35.0 93.0
#  42.0 92.0
#  49.0 93.0
#  56.0 92.0
#  63.0 93.0
#  71.0 92.0
# (0, 3647766397259.375)

# %%
meta.to_csv("8ions_130V_meta")
