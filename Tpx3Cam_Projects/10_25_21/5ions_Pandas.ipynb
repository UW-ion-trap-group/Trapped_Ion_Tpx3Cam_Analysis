# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
import pandas as pd
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())
# Out:
# Mon Oct 25 23:06:01 2021

# %% [markdown]
# <b> 5ions_600sec_350V </b>

# %%
filename = '5ions_600sec_350V'
it = pd.read_csv(f'{filename}.csv')
print(it)
# Out:
#           #Col  #Row            #ToA  #ToT[arb]  #Centroid  Unnamed: 5
# 0          206   153    230012925184       2275          5         NaN
# 1           93    33    230023023360        700          4         NaN
# 2           91    37    230027651584       1625          5         NaN
# 3           90    39    230030235392        700         10         NaN
# 4           96    56    230043063296       1975          7         NaN
# ...        ...   ...             ...        ...        ...         ...
# 10472268    90    46  99789976236288       2850          9         NaN
# 10472269    96    47  99789982251008        700          3         NaN
# 10472270    91    66  99789982853888       1250          6         NaN
# 10472271    89    50  99789998849024       2575          8         NaN
# 10472272    80   127  99790019226112       3700          8         NaN
#
# [10472273 rows x 6 columns]

# %%
it = it.drop(columns = 'Unnamed: 5')
it = it.rename(columns = {'#Col': 'y', '#Row': 'x', '#ToA': 'time', '#ToT[arb]': 'center flux', '#Centroid': 'cluster size'})
ToA = it['time']
it['time'] = it['time'] - ToA[0]
it = it.sort_values(['time'])
it
# Out:
#             y    x            time  center flux  cluster size
# 0         206  153               0         2275             5
# 1          93   33        10098176          700             4
# 2          91   37        14726400         1625             5
# 3          90   39        17310208          700            10
# 4          96   56        30138112         1975             7
# ...       ...  ...             ...          ...           ...
# 10472268   90   46  99559963311104         2850             9
# 10472269   96   47  99559969325824          700             3
# 10472270   91   66  99559969928704         1250             6
# 10472271   89   50  99559985923840         2575             8
# 10472272   80  127  99560006300928         3700             8
#
# [10472273 rows x 5 columns]

# %%
new_filename =" 5ions_600sec_350V"
it.to_csv(new_filename)  ##### changes actual file
it
# Out:
#             y    x            time  center flux  cluster size
# 0         206  153               0         2275             5
# 1          93   33        10098176          700             4
# 2          91   37        14726400         1625             5
# 3          90   39        17310208          700            10
# 4          96   56        30138112         1975             7
# ...       ...  ...             ...          ...           ...
# 10472268   90   46  99559963311104         2850             9
# 10472269   96   47  99559969325824          700             3
# 10472270   91   66  99559969928704         1250             6
# 10472271   89   50  99559985923840         2575             8
# 10472272   80  127  99560006300928         3700             8
#
# [10472273 rows x 5 columns]

# %%
plt.figure(figsize=(5, 5))
filename = str(new_filename)
it = pd.read_csv(filename)
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

plt.xlim(20,80)
plt.ylim(80, 100)
x1 = 30; y1 = 84
x2 = 38; y2 = 85
x3 = 45; y3 = 85
x4 = 52; y4 = 85 
x5 = 73; y5 = 85

#plt.savefig('Ions.svg')

# %%
it.drop("Unnamed: 0",axis=1,inplace=True)

# %%
fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# (0.0, 99560006300928.0)

# %% [markdown]
# <b> 5ions_100sec </b>

# %%
filename = '5ions_100sec'
it = pd.read_csv(f'{filename}.csv')
it = it.drop(columns = 'Unnamed: 5')
it = it.rename(columns = {'#Col': 'y', '#Row': 'x', '#ToA': 'time', '#ToT[arb]': 'center flux', '#Centroid': 'cluster size'})
ToA = it['time']
it['time'] = it['time'] - ToA[0]
it = it.sort_values(['time'])
it
# Out:
#           y    x            time  center flux  cluster size
# 0        18  111               0         1800             7
# 1         1  101         6222592         1375             4
# 2        90   33        33488640         1025             4
# 3        86   32        61788672         2475             8
# 4        89   33        78356736         1100             5
# ...      ..  ...             ...          ...           ...
# 1843738  92   28  16594083671040         1200             5
# 1843739  11   22  16594092120576          850             4
# 1843740  85   52  16594096441856         2550             7
# 1843741  90   32  16594114405376          625             4
# 1843742  90   31  16594115006464          525             2
#
# [1843743 rows x 5 columns]

# %%
new_filename =str(filename)
it.to_csv(new_filename)  ##### changes actual file
it.head(1)
# Out:
#     y    x  time  center flux  cluster size
# 0  18  111     0         1800             7

# %%
plt.figure(figsize=(5, 5))
filename = str(new_filename)
it = pd.read_csv(filename)
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

plt.xlim(20,80)
plt.ylim(80, 100)
x1 = 30; y1 = 84
x2 = 38; y2 = 85
x3 = 45; y3 = 85
x4 = 52; y4 = 85 
x5 = 73; y5 = 85

# %%
it.drop("Unnamed: 0",axis=1,inplace=True)
fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# (0.0, 16594115006464.0)

# %% [markdown]
# <b> 5ions_100sec_no_jumps_350V </b>

# %%
filename = '5ions_100sec_no_jumps_350V'
it = pd.read_csv(f'{filename}.csv')
it = it.drop(columns = 'Unnamed: 5')
it = it.rename(columns = {'#Col': 'y', '#Row': 'x', '#ToA': 'time', '#ToT[arb]': 'center flux', '#Centroid': 'cluster size'})
ToA = it['time']
it['time'] = it['time'] - ToA[0]
it = it.sort_values(['time'])
new_filename =str(filename)
it.to_csv(new_filename)  ##### changes actual file
it.head(1)
# Out:
#     y   x  time  center flux  cluster size
# 0  88  31     0         1350             4

# %%
plt.figure(figsize=(5, 5))
filename = str(new_filename)
it = pd.read_csv(filename)
plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])

plt.xlim(20,80)
plt.ylim(80, 100)
# Out:
# (80.0, 100.0)

# %%
it.drop("Unnamed: 0",axis=1,inplace=True)
fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# (0.0, 16593580341504.0)
