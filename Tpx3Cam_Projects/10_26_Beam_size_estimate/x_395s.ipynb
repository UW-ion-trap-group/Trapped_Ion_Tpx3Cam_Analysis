# %%
import re
import os 
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
import pandas as pd
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())
# Out:
# Thu Oct 28 04:02:28 2021

# %%
filename = 'x_395.5_1'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#     y   x    time  center flux  cluster size
# 0  69  52       0         1750             4
# 1  94  50  838912          725             4

# %%
fig,ax=plt.subplots(figsize=(5, 5))
it = pd.read_csv(filename)
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
ax.set_xlim(25,75)
ax.set_ylim(80,110)

n=1
grid_x=np.linspace(25,75,2)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
print (x1,y1)

fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# 47.0 92.0
# (0.0, 49783639535360.0)

# %%
filename = 'x_395.5_2'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
# Out:
#     y   x     time  center flux  cluster size
# 0  97  23        0          925             4
# 1  93  50  6266880         1000             5

# %%
fig,ax=plt.subplots(figsize=(5, 5))
it = pd.read_csv(filename)
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
ax.set_xlim(25,75)
ax.set_ylim(80,110)

n=1
grid_x=np.linspace(25,75,2)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
print (x1,y1)

fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# 48.0 92.0
# (0.0, 49786725770496.0)

# %%
filename = 'x_395.5_3'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#     y   x     time  center flux  cluster size
# 0  97  23        0          925             4
# 1  93  50  6266880         1000             5

# %%
fig,ax=plt.subplots(figsize=(5, 5))
it = pd.read_csv(filename)
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
ax.set_xlim(25,75)
ax.set_ylim(80,110)

n=1
grid_x=np.linspace(25,75,2)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
print (x1,y1)

fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# 48.0 92.0
# (0.0, 49786725770496.0)

# %%
filename = 'x_395.5'
it = pd.read_csv(filename)
it.drop("Unnamed: 0",axis=1,inplace=True)
it.head(2)
# Out:
#     y   x  time  center flux  cluster size
# 0  84  40     0         1650             6
# 1  88  38  3328          475             2

# %%
fig,ax=plt.subplots(figsize=(5, 5))
it = pd.read_csv(filename)
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
ax.set_xlim(25,75)
ax.set_ylim(80,110)

n=1
grid_x=np.linspace(25,75,2)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
print (x1,y1)

fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
#ax0.set_xlim(x1-5,x1+5)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# 47.0 92.0
# (0.0, 49782536187904.0)

# %%
filename = 'x_395.5'
it = pd.read_csv(filename)

filename = 'x_395.5_1'
it_1 = pd.read_csv(filename)

filename = 'x_395.5_2'
it_2 = pd.read_csv(filename)

filename = 'x_395.5_3'
it_3 = pd.read_csv(filename)

# %%
it_1["time"]+=max(it["time"])
it_2["time"]+=max(it_1["time"])
it_3["time"]+=max(it_2["time"])

# %%
meta=pd.concat([it,it_1,it_2,it_3])
meta.drop("Unnamed: 0",axis=1,inplace=True)
meta
# Out:
#            y    x             time  center flux  cluster size
# 0         84   40                0         1650             6
# 1         88   38             3328          475             2
# 2        162  164         25898496         2200             6
# 3         91   49         34039808          875             3
# 4         83    9         46957824          675             5
# ...      ...  ...              ...          ...           ...
# 1510873   82   48  199139541757184         2325             6
# 1510874   82   48  199139560079872          500             2
# 1510875  123   61  199139601971968         1175             4
# 1510876   94   49  199139625619968         1400             5
# 1510877   95   52  199139627264256         1000             4
#
# [6433057 rows x 5 columns]

# %%
#Checking merger
len(meta)-len(it)-len(it_1)-len(it_2)-len(it_3)
# Out:
# 0

# %%
fig,ax=plt.subplots(figsize=(5, 5))
it=meta
h2d=plt.hist2d(it['x'], it['y'], bins = (256, 256), range = [(0, 256), (0, 256)])
ax.set_xlim(25,75)
ax.set_ylim(80,110)

n=1
grid_x=np.linspace(25,75,2)
ax.set_xticks(grid_x)
ax.grid(axis="x")

a=np.empty((n,2))
for i in range (1,n+1):
    
    temp=it[(it['x']>grid_x[i-1]) & (it['x'] <grid_x[i])]                          # sub-dataframe for x values between upper and lower bounds of box
    temp_2=temp.groupby(["x",'y']).size().idxmax() 
    a[i-1][0]=temp_2[0]; a[i-1][1]=temp_2[1]

x1=a[0][0]; y1=a[0][1]
print (x1,y1)

fig, (ax0) = plt.subplots(ncols=1, figsize=(2,6))
h = ax0.hist2d(it['x'], it['time'], bins = [256, 400])
ax0.set_xlim(x1-40,x1+40)
ax0.set_xlabel('x position')
ax0.set_ylabel('Time (ns)')

#it['time'].max()
start = 0; end = it['time'].max(); duration = end - start
ax0.set_ylim(start, end)
# Out:
# 47.0 92.0
# (0.0, 199139627264256.0)

# %%
meta.to_csv("x_395s_meta")
